# %% [markdown]
# ## Data Observation

# %% [markdown]
# It is observed that the dataset is related to red and white variants of the Portugese "Vinho Verde" wine.
# The data contains only physiochemical (i.e., input) and sensory (i.e., output) variables.
# The inputs consist of **_fixed acidity,volatile acidity,citric acid,residual sugar,chlorides,free sulfur dioxide,total sulfur dioxide,density,pH,sulphates,alcohol_** variables and provide the output variable ie., **_quality_**.

# %% [markdown]
# ## Loading the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading Data

# %%
wine_df = pd.read_csv("winequalityN.csv")

# %%
wine_df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
wine_df.tail()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 6492       0.58     10.5        5
# ...

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
wine_df.columns
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
wine_df.describe(include="O")
# Out:
#          type
# count    6497
# unique      2
# top     white
# freq     4898

# %% [markdown]
# ### Conclusion:
# It is clearly evident that all the columns are numerical except the **'type'** column. And it is observed that *white wine* has more frequency compared to that of *red wine*.
#
# There is no need for performing categorical handling.
# It is also observed that there are some null values in the data from info() function.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Exploring *"fixed acidity"* column

# %%
wine_df["fixed acidity"].mean()
# Out:
# 7.2165793124710955

# %%
wine_df["fixed acidity"].min()
# Out:
# 3.8

# %%
wine_df["fixed acidity"].max()
# Out:
# 15.9

# %%
wine_df["fixed acidity"].median()
# Out:
# 7.0

# %%
wine_df["fixed acidity"].std()
# Out:
# 1.2967498565264803

# %%
wine_df["fixed acidity"].var()
# Out:
# 1.6815601904014472

# %%
wine_df["fixed acidity"].skew()
# Out:
# 1.7228045308969795

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(wine_df["fixed acidity"],kde=True)

plt.title("Histogram plot of fixed acidity",y=1.02)
plt.xlabel("fixed acidity")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(wine_df["fixed acidity"],kind="kde")

plt.title("Density plot of fixed acidity",y=1.02)
plt.xlabel("fixed acidity")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
wine_df["fixed acidity"].quantile(0.10),wine_df["fixed acidity"].quantile(0.25),wine_df["fixed acidity"].quantile(0.50),wine_df["fixed acidity"].quantile(0.75),wine_df["fixed acidity"].quantile(0.90)
# Out:
# (6.0, 6.4, 7.0, 7.7, 8.8)

# %%
sns.boxplot(wine_df["fixed acidity"],orient="h",color="teal")

plt.title("Box plot for fixed acidity",y=1.02)
plt.xlabel("fixed acidity")
plt.show()

# %%
sns.violinplot(wine_df["fixed acidity"],orient="h",color="pink")

plt.title("Violin plot for fixed acidity",y=1.02)
plt.xlabel("fixed acidity")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **fixed acidity** has an asymmetrical distribution i.e., it is skewed with a skewness value of 1.723
#
# * The Density curve of column is centered along mean 7.216 with standard deviation of 1.297.
# * The range of values is from 3.8 to 15.9.
# * Most of the wine is having a fixed acidity in the range from 6 to 8.
# * 10% of wine is having a fixed acidity of 6.0 and below.
# * 25% of wine is having a fixed acidity of 6.4 and below.
# * 50% of wine is having a fixed acidity of 7.0 and below.
# * 75% of wine is having a fixed acidity of 7.7 and below.
# * 90% of wine is having a fixed acidity of 8.8 and below.
# * *fixed acidity* column is having outliers (i.e., extreme values) towards lower as well as higher side.
#
# **fixed acidity** column might be having a good influence on **wine quality**

# %% [markdown]
# #### From the net:
# Acids are major wine constituents and contribute greatly to its taste. In fact, acids impart the sourness or tartness that is a fundamental feature in wine taste.
#
# Wines lacking in acid are "flat". Chemically the acids influence titrable acidity which affects taste and pH which affects  color, stability to oxidation, and consequantly the overall lifespan of a wine. The most abundant of these acids arise in the grapes themselves and carry over into the wine.
#
# However, there are also some acids that arise as a result of the fermentation process from either yeast and/or bacteria.  Traditionally total acidity is divided into two groups, namely the volatile acids (see separate description) and the nonvolatile or fixed acids.

# %% [markdown]
# ### Exploring *"volatile acidity"* column

# %%
wine_df["volatile acidity"].mean()
# Out:
# 0.33969101556480197

# %%
wine_df["volatile acidity"].min()
# Out:
# 0.08

# %%
wine_df["volatile acidity"].max()
# Out:
# 1.58

# %%
wine_df["volatile acidity"].median()
# Out:
# 0.29

# %%
wine_df["volatile acidity"].std()
# Out:
# 0.16464902864429293

# %%
wine_df["volatile acidity"].var()
# Out:
# 0.027109302633509195

# %%
wine_df["volatile acidity"].skew()
# Out:
# 1.4955115856471894

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(wine_df["volatile acidity"],color="orange")

plt.title("Histogram plot of volatile acidity",y=1.02)
plt.xlabel("volatile acidity")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(wine_df["volatile acidity"],kind="kde",color="magenta")

plt.title("Density plot of volatile acidity",y=1.02)
plt.xlabel("volatile acidity")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
wine_df["volatile acidity"].quantile(0.10),wine_df["volatile acidity"].quantile(0.25),wine_df["volatile acidity"].quantile(0.50),wine_df["volatile acidity"].quantile(0.75),wine_df["volatile acidity"].quantile(0.90)
# Out:
# (0.18, 0.23, 0.29, 0.4, 0.59)

# %%
sns.boxplot(wine_df["volatile acidity"],orient="h",color="aqua")

plt.title("Box plot for volatile acidity",y=1.02)
plt.xlabel("volatile acidity")
plt.show()

# %%
sns.violinplot(wine_df["volatile acidity"],orient="h",color="aquamarine")

plt.title("Violin plot for volatile acidity",y=1.02)
plt.xlabel("volatile acidity")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **volatile acidity** has an asymmetrical distribution i.e., it is skewed with a skewness value of 1.495
#
# * The Density curve of column is centered along mean 0.339 with standard deviation of 0.164.
# * The range of values is from 0.08 to 1.58.
# * Most of the wine is having a volatile acidity in the range from 0.15 to 0.45.
# * 10% of wine is having a volatile acidity of 0.18 and below.
# * 25% of wine is having a volatile acidity of 0.23 and below.
# * 50% of wine is having a volatile acidity of 0.29 and below.
# * 75% of wine is having a volatile acidity of 0.40 and below.
# * 90% of wine is having a volatile acidity of 0.59 and below.
# * *volatile acidity* column is having outliers (i.e., extreme values) towards higher side.
#
# **volatile acidity** column might be having some influence on **wine quality**

# %% [markdown]
# #### From the net:
# The total acidity of a wine is the result of the contribution of nonvolatile or fixed acids such as malic and tartaric plus those acids separated by steam volatilization. *A measure of volatile acidity is used routinely as an indicator of wine spoilage.*
#
# VA is often associated with oxidation problems in a wine due to the fact that both result from overexposure to oxygen and/or a lack of sulfur dioxide management. Acetic acid bacteria require oxygen to grow and proliferate.
#
# In 1857, Louis Pasteur set out to determine what was causing beer and wine to spoil. Acetic acid bacteria were the microorganisms that Pasteur eventually identified as the spoilage culprit!

# %% [markdown]
# ### Exploring *"citric acid"* column

# %%
wine_df["citric acid"].mean()
# Out:
# 0.3187218971358176

# %%
wine_df["citric acid"].min()
# Out:
# 0.0

# %%
wine_df["citric acid"].max()
# Out:
# 1.66

# %%
wine_df["citric acid"].median()
# Out:
# 0.31

# %%
wine_df["citric acid"].std()
# Out:
# 0.14526480053397803

# %%
wine_df["citric acid"].var()
# Out:
# 0.021101862274176424

# %%
wine_df["citric acid"].skew()
# Out:
# 0.4730324266140668

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(wine_df["citric acid"],color="brown")

plt.title("Histogram plot of citric acid",y=1.02)
plt.xlabel("citric acid")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(wine_df["citric acid"],kind="kde",color="chartreuse")

plt.title("Density plot of citric acid",y=1.02)
plt.xlabel("citric acid")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
wine_df["citric acid"].quantile(0.10),wine_df["citric acid"].quantile(0.25),wine_df["citric acid"].quantile(0.50),wine_df["citric acid"].quantile(0.75),wine_df["citric acid"].quantile(0.90)
# Out:
# (0.14, 0.25, 0.31, 0.39, 0.49)

# %%
sns.boxplot(wine_df["citric acid"],orient="h",color="chocolate")

plt.title("Box plot for citric acid",y=1.02)
plt.xlabel("citric acid")
plt.show()

# %%
sns.violinplot(wine_df["citric acid"],orient="h",color="coral")

plt.title("Violin plot for citric acid",y=1.02)
plt.xlabel("citric acid")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **citric acid** has a symmetrical distribution i.e., it is not skewed and has a skewness value of 0.473
#
# * The Density curve of column is centered along mean 0.319 with standard deviation of 0.145.
# * The range of values is from 0 to 1.66.
# * Most of the wine is having an amount of citric acid in the range from 0.2 to 0.4.
# * 10% of wine is having an amount of citric acid of 0.14 or below.
# * 25% of wine is having an amount of citric acid of 0.25 or below.
# * 50% of wine is having an amount of citric acid of 0.31 or below.
# * 75% of wine is having an amount of citric acid of 0.39 or below.
# * 90% of wine is having an amount of citric acid of 0.49 or below.
# * *citric acid* column is having outliers (i.e., extreme values) towards both lower and higher sides.
#
# **citric acid** column might contribute to **wine quality**

# %% [markdown]
# #### From the net:
# Citric acid is often added to wines to increase acidity, complement a specific flavor or prevent ferric hazes. It can be added to finished wines to increase acidity and give a “fresh” flavor. The disadvantage of adding citric acid is its microbial instability.

# %% [markdown]
# ### Exploring *"residual sugar"* column

# %%
wine_df["residual sugar"].mean()
# Out:
# 5.444326404926867

# %%
wine_df["residual sugar"].min()
# Out:
# 0.6

# %%
wine_df["residual sugar"].max()
# Out:
# 65.8

# %%
wine_df["residual sugar"].median()
# Out:
# 3.0

# %%
wine_df["residual sugar"].std()
# Out:
# 4.758124742672707

# %%
wine_df["residual sugar"].var()
# Out:
# 22.63975106683421

# %%
wine_df["residual sugar"].skew()
# Out:
# 1.4349998392718966

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(wine_df["residual sugar"],color="crimson")

plt.title("Histogram plot of residual sugar",y=1.02)
plt.xlabel("residual sugar")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(wine_df["residual sugar"],kind="kde",color="cyan")

plt.title("Density plot of residual sugar",y=1.02)
plt.xlabel("residual sugar")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
wine_df["residual sugar"].quantile(0.10),wine_df["residual sugar"].quantile(0.25),wine_df["residual sugar"].quantile(0.50),wine_df["residual sugar"].quantile(0.75),wine_df["residual sugar"].quantile(0.90)
# Out:
# (1.3, 1.8, 3.0, 8.1, 13.0)

# %%
sns.boxplot(wine_df["residual sugar"],orient="h",color="fuchsia")

plt.title("Box plot for residual sugar",y=1.02)
plt.xlabel("residual sugar")
plt.show()

# %%
sns.violinplot(wine_df["residual sugar"],orient="h",color="gold")

plt.title("Violin plot for residual sugar",y=1.02)
plt.xlabel("residual sugar")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **residual sugar** has an asymmetrical distribution i.e., it is skewed with a skewness value of 1.435
#
# * The Density curve of column is centered along mean 5.444 with standard deviation of 4.758.
# * The range of values is from 0.6 to 65.8.
# * Most of the wine is having an amount of residual sugar in the range from 1 to 10.
# * 10% of wine is having an amount of residual sugar of 1.3 or below.
# * 25% of wine is having an amount of residual sugar of 1.8 or below.
# * 50% of wine is having an amount of residual sugar of 3.0 or below.
# * 75% of wine is having an amount of residual sugar of 8.1 or below.
# * 90% of wine is having an amount of residual sugar of 13.0 or below.
# * *residual sugar* column is having outliers (i.e., extreme values) towards higher side.
#
# **residual sugar** column also contributes to **wine quality**

# %% [markdown]
# #### From the net:
# Sweetness in wine is called residual sugar and is usually measured in grams per litre (g/L). Residual sugar is from the natural grape sugars left in a wine after the alcoholic fermentation finishes. The more residual sugar remaining in a wine, the sweeter the wine is. It is certainly not due to the addition of sugar!
#
# Residual sugar comes naturally from the grapes used to make wine. When making wine, grapes have to go through the fermentation process. During this process, most of the sugars within the grape are gradually turned into alcohol. However, there is usually at least some leftover, and this is known as residual sugar. Residual sugar can determine how sweet a wine will be and can affect the categorisation.
#
# Residual sugar is not a bad thing, it is completely natural and one of the elements of wine that makes it so enjoyable.

# %% [markdown]
# ### Exploring *"chlorides"* column

# %%
wine_df["chlorides"].mean()
# Out:
# 0.05604157043879908

# %%
wine_df["chlorides"].min()
# Out:
# 0.009

# %%
wine_df["chlorides"].max()
# Out:
# 0.611

# %%
wine_df["chlorides"].median()
# Out:
# 0.047

# %%
wine_df["chlorides"].std()
# Out:
# 0.03503602522758969

# %%
wine_df["chlorides"].var()
# Out:
# 0.0012275230637483012

# %%
wine_df["chlorides"].skew()
# Out:
# 5.399848762544374

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(wine_df["chlorides"],color="goldenrod")

plt.title("Histogram plot of chlorides",y=1.02)
plt.xlabel("chlorides")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(wine_df["chlorides"],kind="kde",color="green")

plt.title("Density plot of chlorides",y=1.02)
plt.xlabel("chlorides")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
wine_df["chlorides"].quantile(0.10),wine_df["chlorides"].quantile(0.25),wine_df["chlorides"].quantile(0.50),wine_df["chlorides"].quantile(0.75),wine_df["chlorides"].quantile(0.90)
# Out:
# (0.031, 0.038, 0.047, 0.065, 0.086)

# %%
sns.boxplot(wine_df["chlorides"],orient="h",color="grey")

plt.title("Box plot for chlorides",y=1.02)
plt.xlabel("chlorides")
plt.show()

# %%
sns.violinplot(wine_df["chlorides"],orient="h",color="ivory")

plt.title("Violin plot for chlorides",y=1.02)
plt.xlabel("chlorides")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **chlorides** has an asymmetrical distribution i.e., it is skewed with a skewness value of 5.399
#
# * The Density curve of column is centered along mean 0.056 with standard deviation of 0.035.
# * The range of values is from 0.009 to 0.611.
# * Most of the wine is having an amount of chlorides in the range from 0 to 0.1.
# * 10% of wine is having an amount of chlorides of 0.031 or below.
# * 25% of wine is having an amount of chlorides of 0.038 or below.
# * 50% of wine is having an amount of chlorides of 0.047 or below.
# * 75% of wine is having an amount of chlorides of 0.065 or below.
# * 90% of wine is having an amount of chlorides of 0.086 or below.
# * *chlorides* column is having outliers (i.e., extreme values) towards higher side.
#
# **chlorides** column might contribute to **wine quality**

# %% [markdown]
# #### From the net:
# Wine contains from 2 to 4 g/L of salts of mineral acids, along with some organic acids, and they may have a key role on a potential salty taste of a wine, with chlorides being a major contributor to saltiness.

# %% [markdown]
# ### Exploring *"free sulfur dioxide"* column

# %%
wine_df["free sulfur dioxide"].mean()
# Out:
# 30.525319378174544

# %%
wine_df["free sulfur dioxide"].min()
# Out:
# 1.0

# %%
wine_df["free sulfur dioxide"].max()
# Out:
# 289.0

# %%
wine_df["free sulfur dioxide"].median()
# Out:
# 29.0

# %%
wine_df["free sulfur dioxide"].std()
# Out:
# 17.749399772002565

# %%
wine_df["free sulfur dioxide"].var()
# Out:
# 315.04119226636476

# %%
wine_df["free sulfur dioxide"].skew()
# Out:
# 1.2200660740665203

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(wine_df["free sulfur dioxide"],color="maroon")

plt.title("Histogram plot of free sulfur dioxide",y=1.02)
plt.xlabel("free sulfur dioxide")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(wine_df["free sulfur dioxide"],kind="kde",color="khaki")

plt.title("Density plot of free sulfur dioxide",y=1.02)
plt.xlabel("free sulfur dioxide")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
wine_df["free sulfur dioxide"].quantile(0.10),wine_df["free sulfur dioxide"].quantile(0.25),wine_df["free sulfur dioxide"].quantile(0.50),wine_df["free sulfur dioxide"].quantile(0.75),wine_df["free sulfur dioxide"].quantile(0.90)
# Out:
# (9.0, 17.0, 29.0, 41.0, 54.0)

# %%
sns.boxplot(wine_df["free sulfur dioxide"],orient="h",color="lavender")

plt.title("Box plot for free sulfur dioxide",y=1.02)
plt.xlabel("free sulfur dioxide")
plt.show()

# %%
sns.violinplot(wine_df["free sulfur dioxide"],orient="h",color="lightblue")

plt.title("Violin plot for free sulfur dioxide",y=1.02)
plt.xlabel("free sulfur dioxide")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **free sulfur dioxide** has an asymmetrical distribution i.e., it is skewed with a skewness value of 1.22
#
# * The Density curve of column is centered along mean 30.525 with standard deviation of 17.749.
# * The range of values is from 1 to 289.
# * Most of the wine is having an amount of free sulfur dioxide in the range from 0 to 75.
# * 10% of wine is having an amount of free sulfur dioxide of 9 or below.
# * 25% of wine is having an amount of free sulfur dioxide of 17 or below.
# * 50% of wine is having an amount of free sulfur dioxide of 29 or below.
# * 75% of wine is having an amount of free sulfur dioxide of 41 or below.
# * 90% of wine is having an amount of free sulfur dioxide of 54 or below.
# * *free sulfur dioxide* column is having outliers (i.e., extreme values) towards higher side.
#
# **free sulfur dioxide** column might contribute to **wine quality**

# %% [markdown]
# #### From the net:
# Sulfur dioxide (SO2) is important in the winemaking process as it aids in preventing microbial growth and the oxidation of wine. These processes and others consume the SO2 over time, resulting in wines with little SO2 protection. Furthermore, SO2 and sulfiting agents are known to be allergens to many individuals and for that reason their levels need to be monitored and regulated in final wine products.
#
# In winemaking, the use of sulfur dioxide (SO2) is critical. We tend to talk a lot about free SO2 (FSO2) in particular, and not without good reason. The FSO2 and the pH of your wine determine how much SO2 is available in the active, molecular form to help protect the wine from oxidation and spoilage. FSO2 is also something we have to keep a close eye on, because it can be hard to predict how much will be lost, and at what rate, to binding or to aeration. Too much FSO2 can be perceptible to consumers, by masking the wine’s own fruity aromas and inhibiting its ability to undergo the cascade of oxygen-using reactions that happen when it “breathes,” or, in high enough concentrations, by contributing a sharp/bitter/metallic/chemical flavor or sensation.
#
# Total Sulfur Dioxide (TSO2) is the portion of SO2 that is free in the wine, plus the portion that is bound to other chemicals in the wine such as aldehydes, pigments, or sugars.

# %% [markdown]
# ### Exploring *"total sulfur dioxide"* column

# %%
wine_df["total sulfur dioxide"].mean()
# Out:
# 115.7445744189626

# %%
wine_df["total sulfur dioxide"].min()
# Out:
# 6.0

# %%
wine_df["total sulfur dioxide"].max()
# Out:
# 440.0

# %%
wine_df["total sulfur dioxide"].median()
# Out:
# 118.0

# %%
wine_df["total sulfur dioxide"].std()
# Out:
# 56.52185452263032

# %%
wine_df["total sulfur dioxide"].var()
# Out:
# 3194.7200386773857

# %%
wine_df["total sulfur dioxide"].skew()
# Out:
# -0.001177478234437964

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(wine_df["total sulfur dioxide"],color="navy")

plt.title("Histogram plot of total sulfur dioxide",y=1.02)
plt.xlabel("total sulfur dioxide")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(wine_df["total sulfur dioxide"],kind="kde",color="lightgreen")

plt.title("Density plot of total sulfur dioxide",y=1.02)
plt.xlabel("total sulfur dioxide")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
wine_df["total sulfur dioxide"].quantile(0.10),wine_df["total sulfur dioxide"].quantile(0.25),wine_df["total sulfur dioxide"].quantile(0.50),wine_df["total sulfur dioxide"].quantile(0.75),wine_df["total sulfur dioxide"].quantile(0.90)
# Out:
# (30.0, 77.0, 118.0, 156.0, 188.0)

# %%
sns.boxplot(wine_df["total sulfur dioxide"],orient="h",color="lime")

plt.title("Box plot for total sulfur dioxide",y=1.02)
plt.xlabel("total sulfur dioxide")
plt.show()

# %%
sns.violinplot(wine_df["total sulfur dioxide"],orient="h",color="olive")

plt.title("Violin plot for total sulfur dioxide",y=1.02)
plt.xlabel("total sulfur dioxide")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **total sulfur dioxide** has a symmetrical distribution i.e., it is not skewed and has a skewness value of -0.001
#
# * The Density curve of column is centered along mean 115.744 with standard deviation of 56.521.
# * The range of values is from 6 to 440.
# * Most of the wine is having an amount of total sulfur dioxide in the range from 10 to 200.
# * 10% of wine is having an amount of total sulfur dioxide of 30 or below.
# * 25% of wine is having an amount of total sulfur dioxide of 77 or below.
# * 50% of wine is having an amount of total sulfur dioxide of 118 or below.
# * 75% of wine is having an amount of total sulfur dioxide of 156 or below.
# * 90% of wine is having an amount of total sulfur dioxide of 188 or below.
# * *total sulfur dioxide* column is having outliers (i.e., extreme values) towards higher side.
#
# **total sulfur dioxide** column might contribute to **wine quality**

# %% [markdown]
# ### Exploring *"density"* column

# %%
wine_df["density"].mean()
# Out:
# 0.9946966338309989

# %%
wine_df["density"].min()
# Out:
# 0.98711

# %%
wine_df["density"].max()
# Out:
# 1.03898

# %%
wine_df["density"].median()
# Out:
# 0.99489

# %%
wine_df["density"].std()
# Out:
# 0.002998673003719037

# %%
wine_df["density"].var()
# Out:
# 8.992039783233351e-06

# %%
wine_df["density"].skew()
# Out:
# 0.5036017301419994

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(wine_df["density"],color="orchid")

plt.title("Histogram plot of density",y=1.02)
plt.xlabel("density")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(wine_df["density"],kind="kde",color="orange")

plt.title("Density plot of density",y=1.02)
plt.xlabel("density")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
wine_df["density"].quantile(0.10),wine_df["density"].quantile(0.25),wine_df["density"].quantile(0.50),wine_df["density"].quantile(0.75),wine_df["density"].quantile(0.90)
# Out:
# (0.99067, 0.99234, 0.99489, 0.99699, 0.9984)

# %%
sns.boxplot(wine_df["density"],orient="h",color="orangered")

plt.title("Box plot for density",y=1.02)
plt.xlabel("density")
plt.show()

# %%
sns.violinplot(wine_df["density"],orient="h",color="pink")

plt.title("Violin plot for density",y=1.02)
plt.xlabel("density")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **density** has an asymmetrical distribution i.e., it is skewed with a skewness value of 0.503
#
# * The Density curve of column is centered along mean 0.994 with standard deviation of 0.003.
# * The range of values is from 0.98711 to 1.03898.
# * Most of the wine is having density in the range from 0.99 to 1.
# * 10% of wine is having a density of 0.99067 or below.
# * 25% of wine is having a density of 0.99234 or below.
# * 50% of wine is having a density of 0.99489 or below.
# * 75% of wine is having a density of 0.99699 or below.
# * 90% of wine is having a density of 0.9984 or below.
# * *density* column is having outliers (i.e., extreme values) towards higher side.
#
# **density** column might contribute to **wine quality**

# %% [markdown]
# ### Exploring *"pH"* column

# %%
wine_df["pH"].mean()
# Out:
# 3.218395499383477

# %%
wine_df["pH"].min()
# Out:
# 2.72

# %%
wine_df["pH"].max()
# Out:
# 4.01

# %%
wine_df["pH"].median()
# Out:
# 3.21

# %%
wine_df["pH"].std()
# Out:
# 0.16074830655088293

# %%
wine_df["pH"].var()
# Out:
# 0.025840018058976632

# %%
wine_df["pH"].skew()
# Out:
# 0.3869659325699095

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(wine_df["pH"],color="purple")

plt.title("Histogram plot of pH",y=1.02)
plt.xlabel("pH")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(wine_df["pH"],kind="kde",color="red")

plt.title("Density plot of pH",y=1.02)
plt.xlabel("pH")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
wine_df["pH"].quantile(0.10),wine_df["pH"].quantile(0.25),wine_df["pH"].quantile(0.50),wine_df["pH"].quantile(0.75),wine_df["pH"].quantile(0.90)
# Out:
# (3.02, 3.11, 3.21, 3.32, 3.42)

# %%
sns.boxplot(wine_df["pH"],orient="h",color="salmon")

plt.title("Box plot for pH",y=1.02)
plt.xlabel("pH")
plt.show()

# %%
sns.violinplot(wine_df["pH"],orient="h",color="sienna")

plt.title("Violin plot for pH",y=1.02)
plt.xlabel("pH")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **pH** has a symmetrical distribution i.e., it is not skewed and has a skewness value of 0.387
#
# * The Density curve of column is centered along mean 3.218 with standard deviation of 0.161.
# * The range of values is from 2.72 to 4.01.
# * Most of the wine is having pH in the range from 3 to 3.5.
# * 10% of wine is having a pH of 3.02 or below.
# * 25% of wine is having a pH of 3.11 or below.
# * 50% of wine is having a pH of 3.21 or below.
# * 75% of wine is having a pH of 3.32 or below.
# * 90% of wine is having a pH of 3.42 or below.
# * *pH* column is having outliers (i.e., extreme values) towards lower and also towards higher side.
#
# **pH** column contributes to **wine quality**

# %% [markdown]
# #### From the net:
# pH values range from 2.9 to 4.2 in wine. Wine's chemical and biological stability are very dependent on pH value.
#
# Lower pH values are known to improve the stability, so winemakers usually prefer a pH range of 3.0 to 3.5. The wine is so stable in this range that many winemakers believe pH is a crucial guideline in wine-making.

# %% [markdown]
# ### Exploring *"sulphates"* column

# %%
wine_df["sulphates"].mean()
# Out:
# 0.531215154782073

# %%
wine_df["sulphates"].min()
# Out:
# 0.22

# %%
wine_df["sulphates"].max()
# Out:
# 2.0

# %%
wine_df["sulphates"].median()
# Out:
# 0.51

# %%
wine_df["sulphates"].std()
# Out:
# 0.14881412131628308

# %%
wine_df["sulphates"].var()
# Out:
# 0.02214564270313742

# %%
wine_df["sulphates"].skew()
# Out:
# 1.798467034111248

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(wine_df["sulphates"],color="teal")

plt.title("Histogram plot of sulphates",y=1.02)
plt.xlabel("sulphates")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(wine_df["sulphates"],kind="kde",color="tan")

plt.title("Density plot of sulphates",y=1.02)
plt.xlabel("sulphates")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
wine_df["sulphates"].quantile(0.10),wine_df["sulphates"].quantile(0.25),wine_df["sulphates"].quantile(0.50),wine_df["sulphates"].quantile(0.75),wine_df["sulphates"].quantile(0.90)
# Out:
# (0.37, 0.43, 0.51, 0.6, 0.72)

# %%
sns.boxplot(wine_df["sulphates"],orient="h",color="tomato")

plt.title("Box plot for sulphates",y=1.02)
plt.xlabel("sulphates")
plt.show()

# %%
sns.violinplot(wine_df["sulphates"],orient="h",color="turquoise")

plt.title("Violin plot for sulphates",y=1.02)
plt.xlabel("sulphates")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **sulphates** has an asymmetrical distribution i.e., it is skewed with a skewness value of 1.798
#
# * The Density curve of column is centered along mean 0.531 with standard deviation of 0.149.
# * The range of values is from 0.22 to 2.
# * Most of the wine is having an amount of sulphates in the range from 0.35 to 0.6.
# * 10% of wine is having an amount of sulphates of 0.37 or below.
# * 25% of wine is having an amount of sulphates of 0.43 or below.
# * 50% of wine is having an amount of sulphates of 0.51 or below.
# * 75% of wine is having an amount of sulphates of 0.60 or below.
# * 90% of wine is having an amount of sulphates of 0.72 or below.
# * *sulphates* column is having outliers (i.e., extreme values) towards higher side.
#
# **sulphates** column might contribute to **wine quality**

# %% [markdown]
# ### Exploring *"alcohol"* column

# %%
wine_df["alcohol"].mean()
# Out:
# 10.491800831149455

# %%
wine_df["alcohol"].min()
# Out:
# 8.0

# %%
wine_df["alcohol"].max()
# Out:
# 14.9

# %%
wine_df["alcohol"].median()
# Out:
# 10.3

# %%
wine_df["alcohol"].std()
# Out:
# 1.1927117488689747

# %%
wine_df["alcohol"].var()
# Out:
# 1.4225613158900883

# %%
wine_df["alcohol"].skew()
# Out:
# 0.5657177290960251

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(wine_df["alcohol"],color="violet")

plt.title("Histogram plot of alcohol",y=1.02)
plt.xlabel("alcohol")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(wine_df["alcohol"],kind="kde",color="yellow")

plt.title("Density plot of alcohol",y=1.02)
plt.xlabel("alcohol")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
wine_df["alcohol"].quantile(0.10),wine_df["alcohol"].quantile(0.25),wine_df["alcohol"].quantile(0.50),wine_df["alcohol"].quantile(0.75),wine_df["alcohol"].quantile(0.90)
# Out:
# (9.1, 9.5, 10.3, 11.3, 12.3)

# %%
sns.boxplot(wine_df["alcohol"],orient="h",color="yellowgreen")

plt.title("Box plot for alcohol",y=1.02)
plt.xlabel("alcohol")
plt.show()

# %%
sns.violinplot(wine_df["alcohol"],orient="h",color="lavender")

plt.title("Violin plot for alcohol",y=1.02)
plt.xlabel("alcohol")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **alcohol** has an asymmetrical distribution i.e., it is skewed with a skewness value of 0.565
#
# * The Density curve of column is centered along mean 10.491 with standard deviation of 1.193.
# * The range of values is from 8 to 14.9.
# * Most of the wine is having an alcohol content in the range from 9 to 11.
# * 10% of wine is having an alcohol content of 9.1 or below.
# * 25% of wine is having an alcohol content of 9.5 or below.
# * 50% of wine is having an alcohol content of 10.3 or below.
# * 75% of wine is having an alcohol content of 11.3 or below.
# * 90% of wine is having an alcohol content of 12.3 or below.
# * *alcohol* column is having outliers (i.e., extreme values) towards higher side.
#
# **alcohol** column contributes to **wine quality**

# %% [markdown]
# ### Exploring *"quality"* column

# %%
wine_df["quality"].mean()
# Out:
# 5.818377712790519

# %%
wine_df["quality"].min()
# Out:
# 3

# %%
wine_df["quality"].max()
# Out:
# 9

# %%
wine_df["quality"].median()
# Out:
# 6.0

# %%
wine_df["quality"].std()
# Out:
# 0.8732552715311137

# %%
wine_df["quality"].var()
# Out:
# 0.7625747692568792

# %%
wine_df["quality"].value_counts()
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
sns.countplot(x=wine_df["quality"])

plt.title("Count plot of quality",y=1.02)
plt.xlabel("quality")
plt.show()

# %%
wine_df["quality"].quantile(0.10),wine_df["quality"].quantile(0.25),wine_df["quality"].quantile(0.50),wine_df["quality"].quantile(0.75),wine_df["quality"].quantile(0.90)
# Out:
# (5.0, 5.0, 6.0, 6.0, 7.0)

# %% [markdown]
# #### Conclusion:
#
# * The mean of the quality of wine is 5.818
# * The range of values is from 3 to 9.
# * Most of the wine is having a quality of 6 and 5.
# * 25% of wine is having an alcohol content of 5 or below.
# * 75% of wine is having an alcohol content of 6 or below.

# %% [markdown]
# ### Exploring *"type"* column

# %%
wine_df["type"].nunique()
# Out:
# 2

# %%
wine_df["type"].unique()
# Out:
# array(['white', 'red'], dtype=object)

# %%
wine_df["type"].value_counts()
# Out:
# white    4898
# red      1599
# Name: type, dtype: int64

# %%
wine_df["type"].value_counts(normalize=True)*100
# Out:
# white    75.388641
# red      24.611359
# Name: type, dtype: float64

# %%
sns.countplot(x=wine_df["type"])

plt.title("Count plot of type",y=1.02)
plt.xlabel("type")
plt.show()

# %%
count = [4898,1599]
plt.pie(count,labels=["white","red"],autopct="%1.1f%%")

plt.title("Pie chart of type",y=1.02)
plt.show()

# %% [markdown]
# #### Conclusion:
#
# * **Wine type** column consists of two unique values i.e., white wine and red wine.
# * white wine constitute of 75.4% of total wine where as red wine is of 24.6%, with values of 4898 and 1599 respectively.

# %% [markdown]
# ### Plotting Heat Map

# %%
data = wine_df[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']].corr()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data,cmap="crest",annot=True,linewidth=.5)

plt.title("Heat Map",y=1.02)
plt.show()

# %% [markdown]
# #### Conclusion:
#
# * The correlation between the columns has been explored.
# * It is observed that *"alcohol"* column is having strong correlation with *"quality"* compared to other columns.

# %% [markdown]
# ### Exploring *"type"* and *"density"* column

# %%
wine_df.groupby("type")["density"].mean()
# Out:
# type
# red      0.996747
# white    0.994027
# Name: density, dtype: float64

# %% [markdown]
# #### Conclusion:
#
# * There is no big difference in the density of red wine and white wine.

# %% [markdown]
# ### Exploring *"type"* and *"quality"* column

# %%
wine_df.groupby("type")["quality"].mean()
# Out:
# type
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %% [markdown]
# #### Conclusion:
#
# * There is no big difference in the quality of red wine and white wine.

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Handling duplicate data

# %%
wine_df.shape
# Out:
# (6497, 13)

# %%
wine_df.drop_duplicates().shape
# Out:
# (5329, 13)

# %%
wine_df.drop_duplicates(inplace=True)
wine_df.reset_index(drop=True,inplace=True)

# %%
wine_df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            6.2             0.320         0.16             7.0
# ...     ...            ...               ...          ...             ...
# 5324    red            6.8             0.620         0.08             1.9
# 5325    red            6.2             0.600         0.08             2.0
# 5326    red            5.9             0.550         0.10             2.2
# 5327    red            5.9             0.645         0.12             2.0
# 5328    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# #### Insights:
# It is identified that there are some duplicate rows in the data and were dropped using the **drop_duplicates()** function and reindexing of the dataframe has been done using **reset_index()** function.

# %% [markdown]
# ### Checking null values

# %%
wine_df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
wine_df["fixed acidity"].fillna(wine_df["fixed acidity"].median(),inplace=True)
wine_df["volatile acidity"].fillna(wine_df["volatile acidity"].median(),inplace=True)
wine_df["citric acid"].fillna(wine_df["citric acid"].median(),inplace=True)
wine_df["residual sugar"].fillna(wine_df["residual sugar"].median(),inplace=True)
wine_df["chlorides"].fillna(wine_df["chlorides"].median(),inplace=True)
wine_df["pH"].fillna(wine_df["pH"].median(),inplace=True)
wine_df["sulphates"].fillna(wine_df["sulphates"].median(),inplace=True)

# %%
wine_df.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# #### Insights:
# It is identified that there are some (very few) missing values in the data using **isnull()** function and they were replaced by median of those respective columns using **fillna()** function.

# %% [markdown]
# ### Handling outliers

# %% [markdown]
# #### *fixed acidity* column

# %%
wine_df = wine_df[wine_df["fixed acidity"] <= 10]

# %%
wine_df[wine_df["fixed acidity"] > 10]
# Out:
# Empty DataFrame
# Columns: [type, fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %% [markdown]
# #### *volatile acidity* column

# %%
wine_df = wine_df[wine_df["volatile acidity"] <= 0.8]

# %% [markdown]
# #### *citric acid* column

# %%
wine_df = wine_df[wine_df["citric acid"] <= 0.7]

# %% [markdown]
# #### *residual sugar* column

# %%
wine_df = wine_df[wine_df["residual sugar"] <= 20]

# %% [markdown]
# #### *chlorides* column

# %%
wine_df = wine_df[wine_df["chlorides"] <= 0.15]

# %% [markdown]
# #### *free sulfur dioxide* column

# %%
wine_df = wine_df[wine_df["free sulfur dioxide"] <= 100]

# %% [markdown]
# #### *total sulfur dioxide* column

# %%
wine_df = wine_df[wine_df["total sulfur dioxide"] <= 300]

# %% [markdown]
# #### *density* column

# %%
wine_df = wine_df[wine_df["density"] <= 1.01]

# %% [markdown]
# #### *pH* column

# %%
wine_df = wine_df[wine_df["pH"] <= 3.8]

# %% [markdown]
# #### *sulphates* column

# %%
wine_df = wine_df[wine_df["sulphates"] <= 1]

# %%
wine_df.reset_index(drop=True,inplace=True)

# %%
wine_df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            6.3             0.300         0.34             1.6
# 1     white            8.1             0.280         0.40             6.9
# 2     white            7.2             0.230         0.32             8.5
# 3     white            6.2             0.320         0.16             7.0
# 4     white            8.1             0.220         0.43             1.5
# ...     ...            ...               ...          ...             ...
# 4783    red            6.8             0.620         0.08             1.9
# 4784    red            6.2             0.600         0.08             2.0
# 4785    red            5.9             0.550         0.10             2.2
# 4786    red            5.9             0.645         0.12             2.0
# 4787    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# #### Insights:
# The outliers have been handled in the respective columns by applying filtering condition.
